# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('C:/Users/gisic/gisic/cancer/open/train.csv')
test_df = pd.read_csv('C:/Users/gisic/gisic/cancer/open/test.csv')

# %%
train_df
# Out:
#              ID                     img_path mask_path  나이       수술연월일  진단명  \
# 0    BC_01_0001  ./train_imgs/BC_01_0001.png         -  63  2015-10-23    1
# 1    BC_01_0002  ./train_imgs/BC_01_0002.png         -  51  2015-10-28    1
# 2    BC_01_0003  ./train_imgs/BC_01_0003.png         -  37  2015-10-29    1
# 3    BC_01_0004  ./train_imgs/BC_01_0004.png         -  54  2016-03-08    1
# 4    BC_01_0005  ./train_imgs/BC_01_0005.png         -  57  2015-10-30    1
# ..          ...                          ...       ...  ..         ...  ...
# 995  BC_01_3464  ./train_imgs/BC_01_3464.png         -  65  2006-12-22    1
# 996  BC_01_3482  ./train_imgs/BC_01_3482.png         -  48  2006-11-17    1
# 997  BC_01_3485  ./train_imgs/BC_01_3485.png         -  64  2006-11-10    1
# 998  BC_01_3502  ./train_imgs/BC_01_3502.png         -  50  2006-09-22    1
# 999  BC_01_3518  ./train_imgs/BC_01_3518.png         -  76  2010-09-01    1
#
#      암의 위치  암의 개수  암의 장경   NG  ...  ER_Allred_score   PR  PR_Allred_score  \
# 0        2      1   19.0  2.0  ...              8.0  1.0              6.0
# 1        1      1   22.0  3.0  ...              NaN  0.0              NaN
# 2        2      1    NaN  2.0  ...              7.0  1.0              4.0
# 3        2      1    0.0  3.0  ...              NaN  0.0              NaN
# 4        2      1    8.0  2.0  ...              8.0  0.0              NaN
# ..     ...    ...    ...  ...  ...              ...  ...              ...
# 995      2      1   25.0  1.0  ...              NaN  0.0              NaN
# 996      1      1    7.0  1.0  ...              NaN  1.0              NaN
# 997      2      1   15.0  1.0  ...              NaN  1.0              NaN
# 998      1      1    7.0  1.0  ...              NaN  0.0              NaN
# 999      2      1   20.0  3.0  ...              4.0  0.0              2.0
#
#      KI-67_LI_percent  HER2  HER2_IHC  HER2_SISH  HER2_SISH_ratio  \
# 0                12.0   0.0       1.0        NaN              NaN
# 1                70.0   0.0       0.0        NaN              NaN
# 2                 7.0   0.0       1.0        NaN              NaN
# 3                 1.0   1.0       3.0        NaN              NaN
# 4                 8.0   1.0       2.0        1.0             5.44
# ..                ...   ...       ...        ...              ...
# 995               NaN   0.0       0.0        NaN              NaN
# 996               NaN   0.0       0.0        NaN              NaN
# 997               NaN   0.0       0.0        NaN              NaN
# 998               NaN   0.0       0.0        NaN              NaN
# 999               NaN   0.0       1.0        NaN              NaN
#
#      BRCA_mutation  N_category
# 0              NaN           0
# 1              NaN           1
# 2              0.0           0
# 3              NaN           0
# 4              NaN           0
# ..             ...         ...
# 995            NaN           1
# 996            NaN           0
# 997            NaN           1
# 998            NaN           0
# 999            NaN           1
#
# [1000 rows x 28 columns]

# %%
triple_df = train_df.loc[((train_df['ER']==0)|(train_df['ER']).isnull())
                         &((train_df['PR']==0)|(train_df['PR']).isnull())
                         &((train_df['HER2']==0)|(train_df['HER2']).isnull())]

# %%
triple_df['N_category'].value_counts()
# Out:
# 1    55
# 0    54
# Name: N_category, dtype: int64

# %%
triple_df = train_df.loc[((train_df['ER']==0)|(train_df['ER']).isnull())
                         &((train_df['PR']==0)|(train_df['PR']).isnull())
                         &((train_df['HER2']==0)|(train_df['HER2']).isnull())]

# %%
triple_df
# Out:
#              ID                     img_path mask_path  나이       수술연월일  진단명  \
# 1    BC_01_0002  ./train_imgs/BC_01_0002.png         -  51  2015-10-28    1
# 11   BC_01_0013  ./train_imgs/BC_01_0013.png         -  55  2015-11-11    1
# 14   BC_01_0062  ./train_imgs/BC_01_0062.png         -  51  2019-10-30    1
# 15   BC_01_0178  ./train_imgs/BC_01_0178.png         -  36  2019-05-27    1
# 18   BC_01_0214  ./train_imgs/BC_01_0214.png         -  58  2020-06-29    1
# ..          ...                          ...       ...  ..         ...  ...
# 968  BC_01_3247  ./train_imgs/BC_01_3247.png         -  50  2010-04-07    1
# 973  BC_01_3267  ./train_imgs/BC_01_3267.png         -  54  2010-02-16    1
# 991  BC_01_3416  ./train_imgs/BC_01_3416.png         -  69  2009-05-06    1
# 994  BC_01_3447  ./train_imgs/BC_01_3447.png         -  43  2009-01-16    1
# 998  BC_01_3502  ./train_imgs/BC_01_3502.png         -  50  2006-09-22    1
#
#      암의 위치  암의 개수  암의 장경   NG  ...  ER_Allred_score   PR  PR_Allred_score  \
# 1        1      1   22.0  3.0  ...              NaN  0.0              NaN
# 11       2      1    NaN  2.0  ...              NaN  0.0              NaN
# 14       1      1   25.0  3.0  ...              NaN  0.0              NaN
# 15       2      2    2.0  3.0  ...              NaN  0.0              NaN
# 18       1      1    NaN  NaN  ...              NaN  0.0              NaN
# ..     ...    ...    ...  ...  ...              ...  ...              ...
# 968      2      1   25.0  3.0  ...              NaN  0.0              NaN
# 973      2      1    5.0  1.0  ...              NaN  0.0              NaN
# 991      1      1    9.0  1.0  ...              NaN  0.0              NaN
# 994      2      1   10.0  1.0  ...              NaN  0.0              NaN
# 998      1      1    7.0  1.0  ...              NaN  0.0              NaN
#
#      KI-67_LI_percent  HER2  HER2_IHC  HER2_SISH  HER2_SISH_ratio  \
# 1               70.00   0.0       0.0        NaN              NaN
# 11               3.00   0.0       2.0        0.0              0.8
# 14              50.96   0.0       1.0        NaN              NaN
# 15              89.17   0.0       0.0        NaN              NaN
# 18              28.66   NaN       2.0        0.0             30.0
# ..                ...   ...       ...        ...              ...
# 968               NaN   0.0       0.0        NaN              NaN
# 973               NaN   0.0       1.0        NaN              NaN
# 991               NaN   0.0       1.0        NaN              NaN
# 994               NaN   0.0       1.0        NaN              NaN
# 998               NaN   0.0       0.0        NaN              NaN
#
#      BRCA_mutation  N_category
# 1              NaN           1
# 11             NaN           0
# 14             0.0           0
# 15             0.0           0
# 18             NaN           0
# ..             ...         ...
# 968            NaN           1
# 973            NaN           0
# 991            NaN           0
# 994            NaN           0
# 998            NaN           0
#
# [109 rows x 28 columns]

# %%
HER2_df = train_df.loc[((train_df['ER']==0)|(train_df['ER']).isnull())
                         &((train_df['PR']==0)|(train_df['PR']).isnull())
                         &(train_df['HER2']==1)]

# %%
HER2_df
# Out:
#              ID                     img_path mask_path  나이       수술연월일  진단명  \
# 3    BC_01_0004  ./train_imgs/BC_01_0004.png         -  54  2016-03-08    1
# 21   BC_01_0217  ./train_imgs/BC_01_0217.png         -  54  2020-06-30    1
# 29   BC_01_0232  ./train_imgs/BC_01_0232.png         -  44  2020-06-04    1
# 60   BC_01_0298  ./train_imgs/BC_01_0298.png         -  55  2020-03-11    1
# 109  BC_01_0547  ./train_imgs/BC_01_0547.png         -  57  2019-04-22    1
# ..          ...                          ...       ...  ..         ...  ...
# 942  BC_01_3144  ./train_imgs/BC_01_3144.png         -  71  2010-09-20    1
# 945  BC_01_3156  ./train_imgs/BC_01_3156.png         -  65  2010-09-08    1
# 948  BC_01_3171  ./train_imgs/BC_01_3171.png         -  38  2010-08-02    1
# 956  BC_01_3200  ./train_imgs/BC_01_3200.png         -  44  2010-12-28    1
# 963  BC_01_3235  ./train_imgs/BC_01_3235.png         -  55  2010-04-26    1
#
#      암의 위치  암의 개수  암의 장경   NG  ...  ER_Allred_score   PR  PR_Allred_score  \
# 3        2      1    0.0  3.0  ...              NaN  0.0              NaN
# 21       1      1   16.0  NaN  ...              NaN  0.0              NaN
# 29       2      2    9.0  3.0  ...              NaN  0.0              NaN
# 60       2      1   20.0  3.0  ...              NaN  0.0              NaN
# 109      2      1    0.0  2.0  ...              NaN  0.0              NaN
# ..     ...    ...    ...  ...  ...              ...  ...              ...
# 942      2      1   33.0  3.0  ...              NaN  0.0              NaN
# 945      1      1   15.0  3.0  ...              NaN  0.0              NaN
# 948      2      1   35.0  3.0  ...              NaN  0.0              NaN
# 956      2      1   14.0  3.0  ...              NaN  0.0              NaN
# 963      1      1   57.0  2.0  ...              NaN  0.0              NaN
#
#      KI-67_LI_percent  HER2  HER2_IHC  HER2_SISH  HER2_SISH_ratio  \
# 3                1.00   1.0       3.0        NaN              NaN
# 21              17.36   1.0       3.0        NaN              NaN
# 29              47.92   1.0       3.0        NaN              NaN
# 60              34.89   1.0       3.0        NaN              NaN
# 109             28.27   1.0       3.0        NaN              NaN
# ..                ...   ...       ...        ...              ...
# 942             20.00   1.0       2.0        1.0              8.0
# 945               NaN   1.0       2.0        NaN              NaN
# 948               NaN   1.0       3.0        NaN              NaN
# 956               NaN   1.0       2.0        NaN              NaN
# 963               NaN   1.0       3.0        NaN              NaN
#
#      BRCA_mutation  N_category
# 3              NaN           0
# 21             NaN           0
# 29             NaN           1
# 60             NaN           0
# 109            NaN           1
# ..             ...         ...
# 942            NaN           1
# 945            NaN           1
# 948            NaN           1
# 956            NaN           1
# 963            NaN           1
#
# [61 rows x 28 columns]

# %%
ER_PR_df = train_df.loc[((train_df['ER']==1)|(train_df['PR']==1))]

# %%
ER_PR_nHER2_df = train_df.loc[((train_df['ER']==1)|(train_df['PR']==1))
                        &((train_df['HER2']==0)|(train_df['HER2']).isnull())]

# %%
len(ER_PR_nHER2_df)
# Out:
# 647

# %%
ER_PR_df
# Out:
#              ID                     img_path mask_path  나이       수술연월일  진단명  \
# 0    BC_01_0001  ./train_imgs/BC_01_0001.png         -  63  2015-10-23    1
# 2    BC_01_0003  ./train_imgs/BC_01_0003.png         -  37  2015-10-29    1
# 4    BC_01_0005  ./train_imgs/BC_01_0005.png         -  57  2015-10-30    1
# 5    BC_01_0006  ./train_imgs/BC_01_0006.png         -  45  2016-04-26    1
# 6    BC_01_0007  ./train_imgs/BC_01_0007.png         -  57  2015-12-18    1
# ..          ...                          ...       ...  ..         ...  ...
# 993  BC_01_3445  ./train_imgs/BC_01_3445.png         -  50  2009-02-03    1
# 995  BC_01_3464  ./train_imgs/BC_01_3464.png         -  65  2006-12-22    1
# 996  BC_01_3482  ./train_imgs/BC_01_3482.png         -  48  2006-11-17    1
# 997  BC_01_3485  ./train_imgs/BC_01_3485.png         -  64  2006-11-10    1
# 999  BC_01_3518  ./train_imgs/BC_01_3518.png         -  76  2010-09-01    1
#
#      암의 위치  암의 개수  암의 장경   NG  ...  ER_Allred_score   PR  PR_Allred_score  \
# 0        2      1   19.0  2.0  ...              8.0  1.0              6.0
# 2        2      1    NaN  2.0  ...              7.0  1.0              4.0
# 4        2      1    8.0  2.0  ...              8.0  0.0              NaN
# 5        1      2    0.0  3.0  ...              4.0  0.0              NaN
# 6        1      1    NaN  2.0  ...              6.0  1.0              4.0
# ..     ...    ...    ...  ...  ...              ...  ...              ...
# 993      2      1    9.0  1.0  ...              5.0  1.0              5.0
# 995      2      1   25.0  1.0  ...              NaN  0.0              NaN
# 996      1      1    7.0  1.0  ...              NaN  1.0              NaN
# 997      2      1   15.0  1.0  ...              NaN  1.0              NaN
# 999      2      1   20.0  3.0  ...              4.0  0.0              2.0
#
#      KI-67_LI_percent  HER2  HER2_IHC  HER2_SISH  HER2_SISH_ratio  \
# 0                12.0   0.0       1.0        NaN              NaN
# 2                 7.0   0.0       1.0        NaN              NaN
# 4                 8.0   1.0       2.0        1.0             5.44
# 5                 NaN   1.0       3.0        NaN              NaN
# 6                 5.0   1.0       3.0        NaN              NaN
# ..                ...   ...       ...        ...              ...
# 993               NaN   0.0       0.0        NaN              NaN
# 995               NaN   0.0       0.0        NaN              NaN
# 996               NaN   0.0       0.0        NaN              NaN
# 997               NaN   0.0       0.0        NaN              NaN
# 999               NaN   0.0       1.0        NaN              NaN
#
#      BRCA_mutation  N_category
# 0              NaN           0
# 2              0.0           0
# 4              NaN           0
# 5              NaN           0
# 6              NaN           0
# ..             ...         ...
# 993            NaN           0
# 995            NaN           1
# 996            NaN           0
# 997            NaN           1
# 999            NaN           1
#
# [830 rows x 28 columns]

# %%
ER_PR_yHER2_df = train_df.loc[((train_df['ER']==1)|(train_df['PR']==1))
                        &(train_df['HER2']==1)]

# %%
len(ER_PR_yHER2_df)
# Out:
# 183

# %%
len(HER2_df) + len(ER_PR_nHER2_df) + len(triple_df)+len(ER_PR_yHER2_df)
# Out:
# 1000

# %%
print("HER2 임파선 전이율",round(HER2_df['N_category'].mean(), 3))
print("삼중 임파선 전이율",round(triple_df['N_category'].mean(), 3))
print("not HER + ER+PR 임파선 전이율",round(ER_PR_nHER2_df['N_category'].mean(), 3))
print("ER+PR+HER 임파선 전이율",round(ER_PR_yHER2_df['N_category'].mean(), 3))
# Out:
# HER2 임파선 전이율 0.525
# 삼중 임파선 전이율 0.505
# not HER + ER+PR 임파선 전이율 0.546
# ER+PR+HER 임파선 전이율 0.404

# %%
triple_pro = triple_df.drop(['ID','img_path','mask_path','수술연월일','ER_Allred_score'
                            ,'PR_Allred_score','ER','PR','HER2','HER2_IHC','HER2_SISH'
                            ,'HER2_SISH_ratio'],axis=1)

# %%
triple_pro
# Out:
#      나이  진단명  암의 위치  암의 개수  암의 장경   NG   HG  HG_score_1  HG_score_2  \
# 1    51    1      1      1   22.0  3.0  3.0         3.0         3.0
# 11   55    1      2      1    NaN  2.0  NaN         NaN         NaN
# 14   51    1      1      1   25.0  3.0  3.0         3.0         3.0
# 15   36    1      2      2    2.0  3.0  2.0         3.0         3.0
# 18   58    1      1      1    NaN  NaN  NaN         NaN         NaN
# ..   ..  ...    ...    ...    ...  ...  ...         ...         ...
# 968  50    1      2      1   25.0  3.0  3.0         3.0         3.0
# 973  54    1      2      1    5.0  1.0  1.0         3.0         1.0
# 991  69    1      1      1    9.0  1.0  1.0         3.0         1.0
# 994  43    1      2      1   10.0  1.0  2.0         3.0         1.0
# 998  50    1      1      1    7.0  1.0  1.0         1.0         2.0
#
#      HG_score_3  DCIS_or_LCIS_여부  DCIS_or_LCIS_type  T_category  \
# 1           3.0                0                NaN         2.0
# 11          NaN                1                2.0         0.0
# 14          3.0                2                2.0         2.0
# 15          1.0                2                1.0         1.0
# 18          NaN                1                2.0         0.0
# ..          ...              ...                ...         ...
# 968         3.0                0                NaN         2.0
# 973         1.0                0                1.0         1.0
# 991         1.0                0                1.0         1.0
# 994         2.0                0                NaN         1.0
# 998         1.0                0                NaN         1.0
#
#      KI-67_LI_percent  BRCA_mutation  N_category
# 1               70.00            NaN           1
# 11               3.00            NaN           0
# 14              50.96            0.0           0
# 15              89.17            0.0           0
# 18              28.66            NaN           0
# ..                ...            ...         ...
# 968               NaN            NaN           1
# 973               NaN            NaN           0
# 991               NaN            NaN           0
# 994               NaN            NaN           0
# 998               NaN            NaN           0
#
# [109 rows x 16 columns]

# %%
triple_pro.isnull().sum()
# Out:
# 나이                    0
# 진단명                   0
# 암의 위치                 0
# 암의 개수                 0
# 암의 장경                 5
# NG                   12
# HG                    8
# HG_score_1           10
# HG_score_2           10
# HG_score_3           10
# DCIS_or_LCIS_여부       0
# DCIS_or_LCIS_type    95
# T_category            1
# KI-67_LI_percent     36
# BRCA_mutation        98
# N_category            0
# dtype: int64

# %%
triple_pro.loc[triple_pro['암의 장경'].isnull()]
# Out:
#      나이  진단명  암의 위치  암의 개수  암의 장경   NG   HG  HG_score_1  HG_score_2  \
# 11   55    1      2      1    NaN  2.0  NaN         NaN         NaN
# 18   58    1      1      1    NaN  NaN  NaN         NaN         NaN
# 266  52    1      1      1    NaN  1.0  NaN         NaN         NaN
# 314  64    1      2      1    NaN  1.0  NaN         NaN         NaN
# 452  50    1      3      1    NaN  3.0  3.0         3.0         3.0
#
#      HG_score_3  DCIS_or_LCIS_여부  DCIS_or_LCIS_type  T_category  \
# 11          NaN                1                2.0         0.0
# 18          NaN                1                2.0         0.0
# 266         NaN                1                1.0         0.0
# 314         NaN                1                1.0         0.0
# 452         3.0                1                1.0         0.0
#
#      KI-67_LI_percent  BRCA_mutation  N_category
# 11               3.00            NaN           0
# 18              28.66            NaN           0
# 266               NaN            NaN           0
# 314               NaN            NaN           0
# 452             40.69            NaN           0

# %%
triple_pro.loc[triple_pro['NG'].isnull()]
# Out:
#      나이  진단명  암의 위치  암의 개수   암의 장경  NG   HG  HG_score_1  HG_score_2  \
# 18   58    1      1      1     NaN NaN  NaN         NaN         NaN
# 115  54    1      2      1    0.00 NaN  NaN         NaN         NaN
# 783  41    1      1      1   12.00 NaN  3.0         3.0         3.0
# 806  43    1      1      1   30.00 NaN  NaN         NaN         NaN
# 809  61    1      1      1   17.00 NaN  2.0         3.0         3.0
# 825  48    1      1      1   42.00 NaN  3.0         3.0         3.0
# 829  51    1      1      1   22.00 NaN  3.0         3.0         3.0
# 834  33    1      1      1   24.00 NaN  3.0         3.0         3.0
# 851  68    1      2      1   19.00 NaN  2.0         2.0         3.0
# 858  45    4      2      1  110.00 NaN  3.0         NaN         NaN
# 888  41    1      2      1    0.40 NaN  NaN         NaN         NaN
# 927  54    1      2      1    0.35 NaN  NaN         NaN         NaN
#
#      HG_score_3  DCIS_or_LCIS_여부  DCIS_or_LCIS_type  T_category  \
# 18          NaN                1                2.0         0.0
# 115         NaN                1                NaN         NaN
# 783         3.0                0                NaN         1.0
# 806         NaN                0                NaN         2.0
# 809         1.0                0                NaN         1.0
# 825         3.0                0                NaN         2.0
# 829         2.0                0                NaN         2.0
# 834         2.0                0                NaN         2.0
# 851         1.0                0                NaN         1.0
# 858         NaN                0                NaN         3.0
# 888         NaN                0                NaN         1.0
# 927         NaN                1                NaN         1.0
#
#      KI-67_LI_percent  BRCA_mutation  N_category
# 18              28.66            NaN           0
# 115             42.81            NaN           1
# 783             40.00            NaN           0
# 806               NaN            NaN           0
# 809               NaN            NaN           0
# 825               NaN            NaN           1
# 829               NaN            NaN           0
# 834               NaN            NaN           0
# 851               NaN            NaN           1
# 858               NaN            NaN           1
# 888               NaN            NaN           0
# 927               NaN            NaN           0

# %%
train_df.loc[train_df['암의 장경']==0]
# Out:
#              ID                     img_path mask_path  나이       수술연월일  진단명  \
# 3    BC_01_0004  ./train_imgs/BC_01_0004.png         -  54  2016-03-08    1
# 5    BC_01_0006  ./train_imgs/BC_01_0006.png         -  45  2016-04-26    1
# 109  BC_01_0547  ./train_imgs/BC_01_0547.png         -  57  2019-04-22    1
# 115  BC_01_0561  ./train_imgs/BC_01_0561.png         -  54  2019-03-14    1
# 117  BC_01_0567  ./train_imgs/BC_01_0567.png         -  42  2019-02-01    1
#
#      암의 위치  암의 개수  암의 장경   NG  ...  ER_Allred_score   PR  PR_Allred_score  \
# 3        2      1    0.0  3.0  ...              NaN  0.0              NaN
# 5        1      2    0.0  3.0  ...              4.0  0.0              NaN
# 109      2      1    0.0  2.0  ...              NaN  0.0              NaN
# 115      2      1    0.0  NaN  ...              NaN  0.0              NaN
# 117      2      1    0.0  3.0  ...              7.0  1.0              7.0
#
#      KI-67_LI_percent  HER2  HER2_IHC  HER2_SISH  HER2_SISH_ratio  \
# 3                1.00   1.0       3.0        NaN              NaN
# 5                 NaN   1.0       3.0        NaN              NaN
# 109             28.27   1.0       3.0        NaN              NaN
# 115             42.81   0.0       1.0        NaN              NaN
# 117             47.79   0.0       0.0        NaN              NaN
#
#      BRCA_mutation  N_category
# 3              NaN           0
# 5              NaN           0
# 109            NaN           1
# 115            NaN           1
# 117            NaN           1
#
# [5 rows x 28 columns]
